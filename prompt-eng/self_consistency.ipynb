# %% [markdown]
# # Self Consistency Prompting
#
# One of the more advanced techniques in prompt engineering is self-consistency, introduced by `Wang et al. (2022)`.
#
# This method seeks to improve upon the traditional greedy decoding typically used in chain-of-thought (CoT) prompting.
#
# The core concept involves sampling multiple diverse reasoning paths through few-shot CoT and leveraging these variations to determine the most consistent answer. The technique  enhances the effectiveness of CoT prompting, particularly for tasks requiring arithmetic and commonsense reasoning.
#
# ## References:
# * [Wang et al. (2022)](https://arxiv.org/abs/2203.11171)

# %% [markdown]
# ## Running this code on MyBind.org
#
# Note: remember that you will need to **adjust CONFIG** with **proper URL and API_KEY**!
#
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/GenILab-FAU/prompt-eng/HEAD?urlpath=%2Fdoc%2Ftree%2Fprompt-eng%2Fself_consistency.ipynb)

# %%
##
## ZERO SHOT PROMPTING
##

from _pipeline import create_payload, model_req

#### (1) Adjust the inbounding  Prompt, simulating inbounding requests from users or other systems
MESSAGE = "What is 984 * log(2)"

#### (2) Adjust the Prompt Engineering Technique to be applied, simulating Workflow Templates

## @TODO 
PROMPT = MESSAGE 

#### (3) Configure the Model request, simulating Workflow Orchestration
# Documentation: https://github.com/ollama/ollama/blob/main/docs/api.md
payload = create_payload(target="ollama",
                         model="llama3.2:latest", 
                         prompt=PROMPT, 
                         temperature=1.0, 
                         num_ctx=100, 
                         num_predict=100)

### YOU DONT NEED TO CONFIGURE ANYTHING ELSE FROM THIS POINT
# Send out to the model
time, response = model_req(payload=payload)
print(response)
if time: print(f'Time taken: {time}s')
# Out:
# {'model': 'llama3.2:latest', 'prompt': 'What is 984 * log(2)', 'stream': False, 'options': {'temperature': 1.0, 'num_ctx': 100, 'num_predict': 100}}
# To evaluate the expression 984 * log(2), we need to know that log(2) is approximately equal to 0.30103 (base-10 logarithm).
#
# So, we can calculate:
#
# 984 * 0.30103 ≈ 296.31
# Time taken: 10.793s

# %% [markdown]
# In the Below code, enhancements are made to the prompt.

# %%
##
## ZERO SHOT PROMPTING
##

from _pipeline import create_payload, model_req

#### (1) Adjust the inbounding  Prompt, simulating inbounding requests from users or other systems
MESSAGE = ("Perform a requirement analysis to enhance an existing Discord chatbot built using the Owlmind framework "
    "into an educational chatbot. The chatbot should simplify advanced topics for students using toy examples. "
    "Focus on educational improvements and provide:\n"
    "1. Additional educational features required.\n"
    "2. Learning methodologies the chatbot should adopt.\n"
    "3. Ways to personalize learning for different student levels.\n"
    "4. AI model improvements to enhance explanations and engagement.\n"
    "5. Example interactions demonstrating improved learning experience.\n"
    "Format the response with clear sections and bullet points for readability.")

ADDITIONAL=("Generate multiple internal analyses and provide the most consistent, well-reasoned requirement analysis."
            "Format the response with clear sections and bullet points for readability.")

#### (2) Adjust the Prompt Engineering Technique to be applied, simulating Workflow Templates

## @TODO 
PROMPT = MESSAGE + ADDITIONAL

#### (3) Configure the Model request, simulating Workflow Orchestration
# Documentation: https://github.com/ollama/ollama/blob/main/docs/api.md
payload = create_payload(target="open-webui",
                         model="phi4:latest", 
                         prompt=PROMPT, 
                         temperature=1.0, 
                         num_ctx=100, 
                         num_predict=100)

### YOU DONT NEED TO CONFIGURE ANYTHING ELSE FROM THIS POINT
# Send out to the model
time, response = model_req(payload=payload)
print(response)
if time: print(f'Time taken: {time}s')
# Out:
# {'model': 'phi4:latest', 'messages': [{'role': 'user', 'content': 'Perform a requirement analysis to enhance an existing Discord chatbot built using the Owlmind framework into an **educational chatbot**. The chatbot should simplify advanced topics for students using toy examples. Focus on educational improvements and provide:\n1. Additional educational features required.\n2. Learning methodologies the chatbot should adopt.\n3. Ways to personalize learning for different student levels.\n4. AI model improvements to enhance explanations and engagement.\n5. Example interactions demonstrating improved learning experience.\nFormat the response with clear sections and bullet points for readability.Generate multiple internal analyses and provide the most consistent, well-reasoned requirement analysis.Format the response with clear sections and bullet points for readability.'}]}
# # Requirement Analysis: Enhancing a Discord Chatbot into an Educational Tool
#
# ## 1. Additional Educational Features Required
#
# - **Topic-Specific Modules**: Implement modules covering various subjects such as mathematics, science, history, etc., each containing simplified explanations and examples.
# - **Interactive Quizzes**: Integrate quizzes to reinforce learning after each topic or module is covered.
# - **Resource Library**: Provide links to additional reading materials, videos, and external resources for deeper understanding.
# - **Progress Tracking**: Offer a feature that tracks student progress through topics and modules, allowing students to pick up where they left off.
# - **Glossary of Terms**: Include an easily accessible glossary for quick definitions of complex terms encountered during learning.
#
# ## 2. Learning Methodologies the Chatbot Should Adopt
#
# - **Scaffolding**: Gradually introduce more complex ideas by building on simpler concepts, ensuring a solid understanding before moving forward.
# - **Active Learning**: Encourage students to engage with questions and exercises rather than passively receiving information.
# - **Adaptive Learning Paths**: Adjust content difficulty based on student performance, providing challenges appropriate for their current level of understanding.
#
# ## 3. Personalizing Learning for Different Student Levels
#
# - **Skill Assessment**: Begin interactions by assessing the student’s existing knowledge to tailor content complexity.
# - **Customizable Avatars and Themes**: Allow students to personalize chatbot appearance and interaction styles to create a more engaging experience.
# - **Level-Based Content Delivery**: Provide tiered lessons (beginner, intermediate, advanced) so students can choose their learning path or have it suggested by the bot.
#
# ## 4. AI Model Improvements
#
# - **Natural Language Understanding**: Enhance NLP capabilities for better comprehension of student queries and more relevant responses.
# - **Conversational Memory**: Improve context retention to maintain coherent conversations over multiple interactions, referencing past discussions as needed.
# - **Emotion Detection**: Incorporate sentiment analysis to detect frustration or confusion in student messages, allowing the chatbot to offer encouragement or adjust explanations.
# - **Feedback Mechanism**: Implement a feedback loop where students can rate responses and suggestions for improvement, refining AI learning over time.
#
# ## 5. Example Interactions Demonstrating Improved Learning Experience
#
# ### Interaction 1: Mathematics - Understanding Fractions
#
# **Student**: I don't get fractions at all.
#
# **Chatbot**: No worries! Let's start simple. Imagine you have a pizza cut into four equal pieces. If you eat one piece, you've eaten 1 out of 4 pieces, or 1/4 of the pizza. Would you like to try an example with different numbers?
#
# ### Interaction 2: Science - Photosynthesis
#
# **Student**: What is photosynthesis? It's too complex.
#
# **Chatbot**: Think of it as a recipe plants use to make food. They take sunlight, water, and carbon dioxide to produce glucose (food) and oxygen. Let’s break it down further with an analogy. Would you like to see a video or read more about it?
#
# ### Interaction 3: History - The French Revolution
#
# **Student**: How did the French Revolution start?
#
# **Chatbot**: It began due to widespread dissatisfaction with the monarchy's spending and inequality. Imagine if everyone in your school had different rules based on their last names. Unfair, right? This analogy helps understand why people were upset. Would you like a timeline of key events next?
#
# By implementing these features and methodologies, the educational chatbot will provide a more engaging, personalized learning experience that adapts to individual student needs while effectively simplifying complex topics through interactive and relatable methods.
# Time taken: 20.652s

# %%
##
## ZERO SHOT PROMPTING
##

from _pipeline import create_payload, model_req

#### (1) Adjust the inbounding  Prompt, simulating inbounding requests from users or other systems
MESSAGE = ("Perform a requirement analysis to enhance an existing Discord chatbot built using the Owlmind framework "
    "into an educational chatbot. The chatbot should simplify advanced topics for students using toy examples. "
    "Focus on educational improvements and provide:\n"
    "1. Additional educational features required.\n"
    "2. Learning methodologies the chatbot should adopt.\n"
    "3. Ways to personalize learning for different student levels.\n"
    "4. AI model improvements to enhance explanations and engagement.\n"
    "5. Example interactions demonstrating improved learning experience.\n")

ADDITIONAL=("Generate ten internal analyses and provide the most consistent, well-reasoned requirement analysis."
            "Format the response with clear sections and bullet points for readability.")

#### (2) Adjust the Prompt Engineering Technique to be applied, simulating Workflow Templates

## @TODO 
PROMPT = MESSAGE + ADDITIONAL

#### (3) Configure the Model request, simulating Workflow Orchestration
# Documentation: https://github.com/ollama/ollama/blob/main/docs/api.md
payload = create_payload(target="open-webui",
                         model="phi4:latest", 
                         prompt=PROMPT, 
                         temperature=1.0, 
                         num_ctx=100, 
                         num_predict=100)

### YOU DONT NEED TO CONFIGURE ANYTHING ELSE FROM THIS POINT
# Send out to the model
time, response = model_req(payload=payload)
print(response)
if time: print(f'Time taken: {time}s')
# Out:
# {'model': 'phi4:latest', 'messages': [{'role': 'user', 'content': 'Perform a requirement analysis to enhance an existing Discord chatbot built using the Owlmind framework into an educational chatbot. The chatbot should simplify advanced topics for students using toy examples. Focus on educational improvements and provide:\n1. Additional educational features required.\n2. Learning methodologies the chatbot should adopt.\n3. Ways to personalize learning for different student levels.\n4. AI model improvements to enhance explanations and engagement.\n5. Example interactions demonstrating improved learning experience.\nGenerate ten internal analyses and provide the most consistent, well-reasoned requirement analysis.Format the response with clear sections and bullet points for readability.'}]}
# ## Requirement Analysis for Enhancing a Discord Educational Chatbot
#
# ### 1. Additional Educational Features Required
#
# - **Interactive Quizzes**: Implement quizzes after explanations to test comprehension.
# - **Progress Tracking**: Allow students to track their learning progress over time.
# - **Resource Recommendations**: Suggest additional readings or videos based on the topic discussed.
# - **Simplified Language Mode**: Offer a toggle for more straightforward language tailored for beginners.
# - **Concept Mapping**: Visual aids that map out complex topics into simpler, interconnected concepts.
#
# ### 2. Learning Methodologies to Adopt
#
# - **Active Recall**: Incorporate prompts that require students to recall information after explanations.
# - **Spaced Repetition**: Integrate reminders or follow-ups on previously covered material at spaced intervals.
# - **Scaffolded Learning**: Break down complex topics into smaller, manageable parts and build upon them progressively.
# - **Peer Learning**: Facilitate group discussions or study groups through Discord channels.
#
# ### 3. Personalizing Learning for Different Student Levels
#
# - **Adaptive Content Delivery**: Customize explanations based on the student's knowledge level detected from initial assessments.
# - **Difficulty Settings**: Allow students to select difficulty levels (beginner, intermediate, advanced) for each topic.
# - **Feedback Loop**: Use student feedback to adjust future interactions and content complexity.
# - **Learning Profiles**: Create profiles that store individual preferences and progress to tailor future sessions.
#
# ### 4. AI Model Improvements
#
# - **Natural Language Understanding**: Enhance the bot's ability to understand nuanced queries and respond contextually.
# - **Explanation Generation**: Develop models capable of generating clear, concise explanations with multiple examples.
# - **Sentiment Analysis**: Implement sentiment analysis to gauge student frustration or confusion and adjust responses accordingly.
# - **Engagement Metrics**: Track engagement levels to refine interaction strategies.
#
# ### 5. Example Interactions Demonstrating Improved Learning Experience
#
# #### Interaction 1: Simplified Explanation
# **Student**: "What is quantum entanglement?"
# **Bot**: "Imagine having two magical dice that always land on the same number, no matter how far apart they are! That's like quantum entanglement in a nutshell."
#
# #### Interaction 2: Interactive Quiz
# **Bot**: "Let's test your understanding. What happens when one particle of an entangled pair is observed?"
# - A) The other remains unaffected.
# - B) It instantaneously affects the other.
# - C) Nothing happens until both are observed.
#
# **Student**: "B"
# **Bot**: "Correct! Observing one instantly affects its partner."
#
# #### Interaction 3: Adaptive Content
# **Student**: "Can you explain relativity to a beginner?"
# **Bot**: "Sure, think of it like this: time can run slower for someone traveling really fast compared to someone standing still. Let's explore more with simple examples!"
#
# #### Interaction 4: Personalized Learning Path
# **Student**: "I need help with calculus."
# **Bot**: "Let's start with the basics of limits and derivatives. Based on your previous progress, I'll keep it straightforward."
#
# ### Internal Analyses
#
# 1. **User-Centric Design**: Focus on intuitive interactions and user-friendly features to ensure accessibility for all student levels.
# 2. **Scalability**: Ensure the chatbot can handle a growing number of users without compromising performance or quality.
# 3. **Content Diversity**: Maintain a wide range of topics and examples to cater to various educational needs.
# 4. **Feedback Integration**: Regularly incorporate user feedback to refine features and improve learning outcomes.
# 5. **Security and Privacy**: Implement robust data protection measures to safeguard student information.
# 6. **Community Building**: Encourage collaboration and community support among students through group activities.
# 7. **Continuous Learning**: Update the AI model with new educational content and methodologies regularly.
# 8. **Engagement Strategies**: Use gamification elements like badges or points to increase motivation and participation.
# 9. **Multimodal Learning**: Integrate text, audio, and visual content to cater to different learning styles.
# 10. **Performance Analytics**: Provide detailed analytics for educators to understand student engagement and comprehension.
#
# By focusing on these areas, the educational chatbot can become a more effective tool for simplifying advanced topics and enhancing the learning experience for students of all levels.
# Time taken: 23.788s

# %% [markdown]
# Further experimentation with parameters. Changed the temperature to 0.5

# %%
##
## SELF CONSISTENCY PROMPTING
##

from _pipeline import create_payload, model_req

#### (1) Adjust the inbounding  Prompt, simulating inbounding requests from users or other systems
MESSAGE = ("Perform a requirement analysis to enhance an existing Discord chatbot built using the Owlmind framework "
    "into an educational chatbot. The chatbot should simplify advanced topics for students using toy examples. "
    "Focus on educational improvements and provide:\n"
    "1. Additional educational features required.\n"
    "2. Learning methodologies the chatbot should adopt.\n"
    "3. Ways to personalize learning for different student levels.\n"
    "4. AI model improvements to enhance explanations and engagement.\n"
    "5. Example interactions demonstrating improved learning experience.\n")

ADDITIONAL=("Generate ten internal analyses and provide the most consistent, well-reasoned requirement analysis."
            "Format the response with clear sections and bullet points for readability.")

#### (2) Adjust the Prompt Engineering Technique to be applied, simulating Workflow Templates

## @TODO 
PROMPT = MESSAGE + ADDITIONAL

#### (3) Configure the Model request, simulating Workflow Orchestration
# Documentation: https://github.com/ollama/ollama/blob/main/docs/api.md
payload = create_payload(target="open-webui",
                         model="phi4:latest", 
                         prompt=PROMPT, 
                         temperature=0.5, 
                         num_ctx=100, 
                         num_predict=100)

### YOU DONT NEED TO CONFIGURE ANYTHING ELSE FROM THIS POINT
# Send out to the model
time, response = model_req(payload=payload)
print(response)
if time: print(f'Time taken: {time}s')
# Out:
# {'model': 'phi4:latest', 'messages': [{'role': 'user', 'content': 'Perform a requirement analysis to enhance an existing Discord chatbot built using the Owlmind framework into an educational chatbot. The chatbot should simplify advanced topics for students using toy examples. Focus on educational improvements and provide:\n1. Additional educational features required.\n2. Learning methodologies the chatbot should adopt.\n3. Ways to personalize learning for different student levels.\n4. AI model improvements to enhance explanations and engagement.\n5. Example interactions demonstrating improved learning experience.\nGenerate ten internal analyses and provide the most consistent, well-reasoned requirement analysis.Format the response with clear sections and bullet points for readability.'}]}
# # Requirement Analysis: Enhancing Discord Chatbot into an Educational Platform
#
# ## 1. Additional Educational Features Required
#
# - **Interactive Quizzes**: Incorporate quizzes after explanations to reinforce learning.
# - **Progress Tracking**: Implement a system to track student progress over time.
# - **Resource Recommendations**: Suggest additional resources like articles, videos, or books for further reading.
# - **To-Do Lists and Study Plans**: Allow students to create personalized study plans and checklists.
# - **Peer Interaction Features**: Facilitate group discussions or study sessions among peers.
#
# ## 2. Learning Methodologies the Chatbot Should Adopt
#
# - **Socratic Method**: Encourage critical thinking by asking probing questions related to the topic.
# - **Experiential Learning**: Use simulations or real-world scenarios to illustrate concepts practically.
# - **Spaced Repetition**: Implement a system for reviewing topics at increasing intervals to enhance memory retention.
# - **Problem-Based Learning (PBL)**: Pose problems that require students to apply their knowledge in new contexts.
#
# ## 3. Ways to Personalize Learning for Different Student Levels
#
# - **Adaptive Content Delivery**: Adjust the complexity of explanations based on user input and performance metrics.
# - **Customized Learning Paths**: Offer tailored learning paths depending on a student’s current understanding and goals.
# - **Skill Assessment**: Conduct initial assessments to gauge students’ starting levels and customize content accordingly.
# - **Feedback Mechanisms**: Provide real-time feedback that is specific to the individual's progress and areas of difficulty.
#
# ## 4. AI Model Improvements to Enhance Explanations and Engagement
#
# - **Natural Language Understanding (NLU) Enhancement**: Improve understanding of student queries to provide more relevant responses.
# - **Contextual Memory**: Develop memory capabilities to remember past interactions, allowing for a continuous learning experience.
# - **Emotion Detection**: Integrate emotion recognition to adapt responses based on the student’s mood and engagement level.
# - **Interactive Visuals**: Utilize AI to generate diagrams or visual aids that explain complex concepts more effectively.
#
# ## 5. Example Interactions Demonstrating Improved Learning Experience
#
# ### Scenario: Teaching Basic Programming Concepts
#
# **Interaction 1**
#
# *Student*: Can you explain what a loop is in programming?
#
# *Chatbot*: Absolutely! Imagine you have a task like cleaning your room repeatedly every weekend. Instead of saying, "Clean the room," over and over again, a loop lets you say it once: "While weekends happen, clean the room." In programming, a loop does something similar by executing a block of code multiple times until a condition is met.
#
# *Follow-up Quiz*: What types of loops are commonly used in Python?
# a) For, While
# b) For, If
# c) While, Else
#
# **Interaction 2**
#
# *Student*: I struggle with understanding recursion. Can you help?
#
# *Chatbot*: Sure! Think about a stack of nesting dolls. You open the first doll and find another smaller one inside, which also opens to reveal an even smaller one, and so on until there are no more dolls inside. Each time you open a doll, it's like calling a function again in recursion—it repeats the action with a smaller version each time until reaching the smallest doll.
#
# *Personalized Content*: Would you prefer another example or perhaps a small exercise to practice?
#
# ### Scenario: Learning Algebra
#
# **Interaction 3**
#
# *Student*: How do I solve quadratic equations?
#
# *Chatbot*: Let's tackle it step-by-step. First, recall that a quadratic equation is like solving for how many different sized squares (x^2) can fit into a given area when you also have smaller rectangles (x). We use the formula x = [-b ± sqrt(b²-4ac)] / 2a to find solutions.
#
# *Adaptive Quiz*: Try solving this equation: x² - 5x + 6 = 0. Would you like hints if needed?
#
# ## Consistent, Well-Reasoned Requirement Analysis
#
# To transform the Discord chatbot into an effective educational tool using the Owlmind framework, the focus should be on interactivity and personalization:
#
# 1. **Interactive Features**: By introducing quizzes, progress tracking, and resource recommendations, students engage with the material actively, enhancing retention.
#
# 2. **Adaptive Learning Methodologies**: Adopting methods like Socratic questioning or problem-based learning encourages critical thinking and application of knowledge.
#
# 3. **Personalized Educational Journeys**: Tailoring content delivery based on individual assessments ensures that each student receives appropriate challenges and support.
#
# 4. **AI Model Enhancements**: Improved NLU, contextual memory, emotion detection, and visual aids will make the chatbot more intuitive, engaging, and effective in delivering complex concepts.
#
# 5. **Example Interactions**: Through carefully crafted scenarios like those above, students can see how theoretical knowledge is applied practically, making learning both accessible and enjoyable.
#
# By implementing these strategies, the enhanced educational bot will be well-equipped to simplify advanced topics for a diverse student audience using interactive and personalized approaches.
# Time taken: 20.833s
