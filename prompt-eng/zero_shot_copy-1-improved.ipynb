# %% [markdown]
# # Zero-Shot Prompting
#
# Zero-shot prompting refers to a technique in prompt engineering where you provide a model with a task without any prior examples. The model is expected to understand and generate a response or complete the task purely based on the given instruction.
#
# In other words, the model is given "zero" prior training examples or demonstrations in the prompt and relies on its pre-trained knowledge to infer what is needed.
#
# ## References:
# * [Wei et al. (2022)](https://arxiv.org/pdf/2109.01652.pdf): demonstrate how instruction tuning improves zero-shot learning

# %% [markdown]
# ## Running this code on MyBind.org
#
# Note: remember that you will need to **adjust CONFIG** with **proper URL and API_KEY**!
#
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/GenILab-FAU/prompt-eng/HEAD?urlpath=%2Fdoc%2Ftree%2Fprompt-eng%2Fzero_shot.ipynb)

# %%
##
## ZERO-SHOT PROMPTING FOR REQUIREMENT ANALYSIS
##

from _pipeline import create_payload, model_req

#### (1) Adjust the inbounding Prompt, simulating inbounding requests from users or other systems
MESSAGE = ("Perform a requirement analysis to enhance an existing Discord chatbot built using the Owlmind framework "
    "into an educational chatbot. The chatbot should simplify advanced topics for students using toy examples. "
    "Focus on educational improvements and provide:\n"
    "1. Additional educational features required.\n"
    "2. Learning methodologies the chatbot should adopt.\n"
    "3. Ways to personalize learning for different student levels.\n"
    "4. AI model improvements to enhance explanations and engagement.\n"
    "5. Example interactions demonstrating improved learning experience.\n"
    "Format the response with clear sections and bullet points for readability.")

#### (2) Adjust the Prompt Engineering Technique to be applied, simulating Workflow Templates
PROMPT = MESSAGE 

#### (3) Configure the Model request, simulating Workflow Orchestration
# Documentation: https://github.com/ollama/ollama/blob/main/docs/api.md
payload = create_payload(target="open-webui",
                         model="phi4:latest", 
                         prompt=PROMPT, 
                         temperature=0.7, 
                         num_ctx=2048, 
                         num_predict=1200) #Initially 300, changed it to 900. Then to 2000 and next to 1200

### YOU DON’T NEED TO CONFIGURE ANYTHING ELSE FROM THIS POINT
# Send out to the model
response_time, response = model_req(payload=payload)
print(response)
if response_time: print(f'Time taken: {response_time}s')
# Out:
# {'model': 'phi4:latest', 'messages': [{'role': 'user', 'content': 'Perform a requirement analysis to enhance an existing Discord chatbot built using the Owlmind framework into an **educational chatbot**. The chatbot should simplify advanced topics for students using toy examples. Focus on educational improvements and provide:\n1. Additional educational features required.\n2. Learning methodologies the chatbot should adopt.\n3. Ways to personalize learning for different student levels.\n4. AI model improvements to enhance explanations and engagement.\n5. Example interactions demonstrating improved learning experience.\nFormat the response with clear sections and bullet points for readability.'}]}
# # Requirement Analysis for Enhancing a Discord Chatbot into an Educational Chatbot
#
# To transform an existing chatbot built using the Owlmind framework into an educational tool, we need to focus on several key areas: additional features, learning methodologies, personalization, AI improvements, and example interactions. Below is a detailed analysis.
#
# ## 1. Additional Educational Features Required
#
# - **Topic Coverage Expansion**:
#   - Include a wide range of subjects such as mathematics, science, history, etc.
#   - Regularly update content to include recent developments in various fields.
#
# - **Interactive Quizzes**:
#   - Implement quizzes with instant feedback to reinforce learning.
#   - Use varying difficulty levels based on the student's progress.
#
# - **Progress Tracking**:
#   - Allow students to track their learning journey and achievements.
#   - Provide reports or summaries of topics covered and performance metrics.
#
# - **Resource Recommendations**:
#   - Suggest external resources like articles, videos, or books for further reading.
#
# - **Homework Assistance**:
#   - Offer step-by-step guidance on solving problems without giving direct answers.
#
# ## 2. Learning Methodologies the Chatbot Should Adopt
#
# - **Scaffolding**:
#   - Break down complex topics into simpler, manageable parts.
#   - Gradually increase complexity as the student's understanding improves.
#
# - **Experiential Learning**:
#   - Use real-world examples and scenarios to explain abstract concepts.
#   - Encourage students to apply knowledge through problem-solving activities.
#
# - **Active Recall and Spaced Repetition**:
#   - Implement features that prompt students to recall information periodically.
#   - Use spaced repetition algorithms to schedule reviews of learned material.
#
# - **Peer Learning**:
#   - Facilitate group discussions or study groups within the Discord server.
#
# ## 3. Ways to Personalize Learning for Different Student Levels
#
# - **Adaptive Learning Paths**:
#   - Customize learning paths based on initial assessments or ongoing performance.
#   - Offer beginner, intermediate, and advanced tracks for each topic.
#
# - **Preference Settings**:
#   - Allow students to set preferences for learning styles (visual, auditory, kinesthetic).
#   - Adjust content presentation accordingly (e.g., more diagrams for visual learners).
#
# - **Performance-Based Adaptation**:
#   - Analyze quiz results and interaction history to adjust difficulty levels.
#   - Provide additional support or challenges as needed.
#
# ## 4. AI Model Improvements to Enhance Explanations and Engagement
#
# - **Natural Language Processing (NLP) Enhancements**:
#   - Improve the bot's ability to understand and respond to complex queries.
#   - Use sentiment analysis to adjust responses based on student emotions.
#
# - **Conversational Context Awareness**:
#   - Maintain context across multiple interactions for a seamless learning experience.
#   - Remember previous questions or topics discussed in earlier sessions.
#
# - **Dynamic Content Generation**:
#   - Generate personalized examples and explanations using AI models.
#   - Create visual aids like graphs or charts on-the-fly to illustrate concepts.
#
# - **Engagement Features**:
#   - Use gamification elements (e.g., badges, leaderboards) to motivate students.
#   - Implement interactive elements like polls or reaction-based feedback.
#
# ## 5. Example Interactions Demonstrating Improved Learning Experience
#
# ### Interaction 1: Explaining a Math Concept
# **Student**: "Can you explain what derivatives are?"
#
# **Chatbot**:
# - *Scaffolding*: "Sure! Think of derivatives as a way to measure how something changes at any given point. Imagine driving a car; the speedometer shows your rate of change in position over time."
# - *Interactive Element*: "Would you like to try an example with a simple function, or see a visual representation?"
#
# ### Interaction 2: Personalized Learning Path
# **Student**: "I'm having trouble with calculus."
#
# **Chatbot**:
# - *Adaptive Learning Path*: "Let's start by assessing your current understanding. How comfortable are you with basic differentiation?"
# - *Feedback Loop*: After the assessment, offer tailored resources or exercises.
#
# ### Interaction 3: Engaging Quiz
# **Student**: "I want to test my knowledge on photosynthesis."
#
# **Chatbot**:
# - *Interactive Quiz*: "Great! Let's start a quiz. Here’s your first question..."
# - *Spaced Repetition*: After the quiz, suggest reviewing key points and schedule future quizzes.
#
# ### Interaction 4: Resource Recommendation
# **Student**: "I need more information on World War II."
#
# **Chatbot**:
# - *Resource Suggestion*: "Here are some books and documentaries that might help. Would you like a summary or key points from each?"
#
# By incorporating these features and methodologies, the educational chatbot will provide a comprehensive, personalized, and engaging learning experience for students of all levels.
# Time taken: 25.643s

# %% [markdown]
# In the above process, we have tried understanding zero-shot technique and how it works. In the example given by the professor,

# %% [markdown]
# ---
#
# ## How to improve it?
#
# * **Use Clear and Concise Instructions**: Be specific about the task and desired format.
#     * Bad Prompt: “Summarize this.”
#     * Good Prompt: “Summarize this paragraph in one sentence.”
# * **Add Context**: Providing background can help the model interpret ambiguous prompts better.
# * **Specify Output Format**: If a particular structure is needed, describe it in the instruction.
