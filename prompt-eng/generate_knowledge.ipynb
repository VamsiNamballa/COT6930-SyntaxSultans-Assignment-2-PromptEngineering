# %% [markdown]
# First Experimentation

# %%
##
## GENERATE KNOWLEDGE PROMPTING FOR REQUIREMENT ANALYSIS
##

from _pipeline import create_payload, model_req

#### (1) Adjust the inbounding Prompt, simulating inbounding requests from users or other systems
MESSAGE = ("Before performing the requirement analysis, first generate foundational knowledge on how AI-powered "
    "educational chatbots improve student learning, focusing on:\n"
    "- Cognitive and pedagogical principles behind effective tutoring.\n"
    "- How simplifying complex topics using toy examples improves retention.\n"
    "- The role of personalization in adaptive learning systems.\n"
    "- How AI models can be optimized to improve explanation clarity and engagement.\n"
    "- Key challenges in AI-driven education and how to address them.\n\n"
    "After generating this knowledge, proceed with the requirement analysis to enhance an existing Discord chatbot "
    "built using the Owlmind framework into an educational chatbot. The chatbot should simplify advanced topics for "
    "students using toy examples. Focus on educational improvements and provide:\n"
    "1. Additional educational features required, informed by the generated knowledge.\n"
    "2. Learning methodologies the chatbot should adopt based on effective AI tutoring strategies.\n"
    "3. Ways to personalize learning for different student levels, leveraging AI-driven adaptability.\n"
    "4. AI model improvements to enhance explanations and engagement.\n"
    "5. Example interactions demonstrating improved learning experience.\n\n"
    "First, generate the relevant knowledge step-by-step, then use that knowledge to structure the final requirement analysis. "
    "Format the response with clear sections and bullet points for readability.")

#### (2) Adjust the Prompt Engineering Technique to be applied, simulating Workflow Templates
PROMPT = MESSAGE 

#### (3) Configure the Model request, simulating Workflow Orchestration
# Documentation: https://github.com/ollama/ollama/blob/main/docs/api.md
payload = create_payload(target="open-webui",
                         model="phi4:latest", 
                         prompt=PROMPT, 
                         temperature=0.7, 
                         num_ctx=2048, 
                         num_predict=1200) #Initially 300, changed it to 900. Then to 2000 and next to 1200

### YOU DON’T NEED TO CONFIGURE ANYTHING ELSE FROM THIS POINT
# Send out to the model
response_time, response = model_req(payload=payload)
print(response)
if response_time: print(f"Time taken: {response_time}s")
# Out:
# {'model': 'phi4:latest', 'messages': [{'role': 'user', 'content': 'Before performing the requirement analysis, first generate foundational knowledge on how AI-powered educational chatbots improve student learning, focusing on:\n- Cognitive and pedagogical principles behind effective tutoring.\n- How simplifying complex topics using toy examples improves retention.\n- The role of personalization in adaptive learning systems.\n- How AI models can be optimized to improve explanation clarity and engagement.\n- Key challenges in AI-driven education and how to address them.\n\nAfter generating this knowledge, proceed with the requirement analysis to enhance an existing Discord chatbot built using the Owlmind framework into an educational chatbot. The chatbot should simplify advanced topics for students using toy examples. Focus on educational improvements and provide:\n1. Additional educational features required, informed by the generated knowledge.\n2. Learning methodologies the chatbot should adopt based on effective AI tutoring strategies.\n3. Ways to personalize learning for different student levels, leveraging AI-driven adaptability.\n4. AI model improvements to enhance explanations and engagement.\n5. Example interactions demonstrating improved learning experience.\n\nFirst, generate the relevant knowledge step-by-step, then use that knowledge to structure the final requirement analysis. Format the response with clear sections and bullet points for readability.'}]}
# ### Foundational Knowledge on AI-Powered Educational Chatbots
#
# #### Cognitive and Pedagogical Principles Behind Effective Tutoring
#
# - **Scaffolding**: Gradually building a student's understanding by providing support structures, which are removed as they gain independence.
# - **Zone of Proximal Development (ZPD)**: Tailoring instruction to the space between what learners can do without help and what they can achieve with guidance.
# - **Feedback Mechanisms**: Offering timely, specific feedback to reinforce learning and correct misunderstandings.
# - **Active Learning**: Encouraging students to engage actively in the learning process through problem-solving and application of concepts.
#
# #### Simplifying Complex Topics Using Toy Examples
#
# - **Concrete Representation**: Using simple, relatable examples to represent complex ideas can make abstract concepts more understandable.
# - **Analogical Reasoning**: Drawing parallels between new information and familiar scenarios helps solidify understanding.
# - **Incremental Complexity**: Introducing complexity gradually within toy examples helps build confidence and comprehension.
#
# #### The Role of Personalization in Adaptive Learning Systems
#
# - **Individualized Learning Paths**: Tailoring content to fit the unique pace, style, and level of each learner enhances engagement and effectiveness.
# - **Data-Driven Insights**: Utilizing data analytics to understand student performance and preferences for better personalization.
# - **Dynamic Content Adjustment**: Continuously adapting learning materials based on real-time feedback and performance metrics.
#
# #### Optimizing AI Models for Clarity and Engagement
#
# - **Natural Language Processing (NLP)**: Enhancing language models to interpret and generate human-like responses that are clear and contextually relevant.
# - **Interactive Dialogue Systems**: Designing chatbots to engage in interactive conversations, promoting active learning through dialogue.
# - **Multimodal Learning**: Integrating text with other forms of media (e.g., images, videos) for richer explanations.
#
# #### Key Challenges in AI-Driven Education
#
# - **Bias and Fairness**: Ensuring AI systems do not perpetuate biases present in training data or educational materials.
# - **Scalability**: Developing systems that can effectively serve a large number of students with diverse needs.
# - **Privacy Concerns**: Safeguarding student data while using it to personalize learning experiences.
#
# ### Requirement Analysis for Enhancing an Educational Chatbot
#
# #### 1. Additional Educational Features Required
#
# - **Interactive Problem Solving**: Implement features allowing students to work through problems step-by-step, with hints and guidance provided by the chatbot.
# - **Progress Tracking**: Enable tracking of student progress over time, offering insights into areas of strength and improvement.
# - **Peer Collaboration**: Facilitate collaborative learning opportunities where students can discuss topics or solve problems together.
#
# #### 2. Learning Methodologies to Adopt
#
# - **Scaffolded Instruction**: Integrate scaffolding techniques by providing hints, examples, and step-by-step guidance tailored to the student's current understanding level.
# - **Active Recall Techniques**: Encourage active recall through quizzes and flashcards that require students to retrieve information actively rather than passively reviewing it.
#
# #### 3. Personalizing Learning for Different Student Levels
#
# - **Adaptive Difficulty**: Use AI algorithms to adjust the difficulty of problems based on real-time performance analysis, ensuring content remains challenging yet achievable.
# - **Preference-Based Content Delivery**: Allow students to express preferences (e.g., visual vs. textual explanations) and tailor content delivery accordingly.
#
# #### 4. AI Model Improvements for Explanation Clarity and Engagement
#
# - **Enhanced NLP Capabilities**: Improve the chatbot's ability to understand nuanced queries and provide clear, contextually relevant responses.
# - **Emotion Recognition**: Incorporate sentiment analysis to gauge student emotions and adjust interactions to maintain engagement (e.g., offering encouragement if frustration is detected).
#
# #### 5. Example Interactions Demonstrating Improved Learning Experience
#
# **Scenario: Explaining a Basic Concept in Algebra**
#
# - *Student*: "I don't understand how to solve linear equations."
# - *Chatbot*: "No worries! Let's start with a simple example. Imagine you have two apples and you get three more. How many do you have now? If we write this as an equation, it looks like 2 + x = 5. Here, 'x' is the number of apples we got. Can you solve for 'x'?"
# - *Student*: "Is it 3?"
# - *Chatbot*: "Exactly! Now, let's try another one: Solve 4 + y = 9."
# - *Student*: "y equals 5!"
# - *Chatbot*: "Perfect! You're getting the hang of it. Let’s move on to equations with variables on both sides next."
#
# This interaction demonstrates the use of toy examples and personalized feedback to enhance understanding, leveraging AI's capability for tailored guidance.
#
# ---
#
# By incorporating these elements into an educational chatbot built using the Owlmind framework, we can significantly enhance its effectiveness as a learning tool that simplifies advanced topics through engaging, personalized interactions.
# Time taken: 26.671s

# %%
##
## GENERATE KNOWLEDGE PROMPTING FOR REQUIREMENT ANALYSIS
##

from _pipeline import create_payload, model_req

#### (1) Adjust the inbounding Prompt, simulating inbounding requests from users or other systems
MESSAGE = ("Before performing the requirement analysis, first generate foundational knowledge on how AI-powered "
    "educational chatbots improve student learning, focusing on:\n"
    "- Cognitive and pedagogical principles behind effective tutoring.\n"
    "- How simplifying complex topics using toy examples improves retention.\n"
    "- The role of personalization in adaptive learning systems.\n"
    "- How AI models can be optimized to improve explanation clarity and engagement.\n"
    "- Key challenges in AI-driven education and how to address them.\n\n"
    "After generating this knowledge, proceed with the requirement analysis to enhance an existing Discord chatbot "
    "built using the Owlmind framework into an educational chatbot. The chatbot should simplify advanced topics for "
    "students using toy examples. Focus on educational improvements and provide:\n"
    "1. Additional educational features required, informed by the generated knowledge.\n"
    "2. Learning methodologies the chatbot should adopt based on effective AI tutoring strategies.\n"
    "3. Ways to personalize learning for different student levels, leveraging AI-driven adaptability.\n"
    "4. AI model improvements to enhance explanations and engagement.\n"
    "5. Example interactions demonstrating improved learning experience.\n\n"
    "First, generate the relevant knowledge step-by-step, then use that knowledge to structure the final requirement analysis. "
    "Format the response with clear sections and bullet points for readability.")

#### (2) Adjust the Prompt Engineering Technique to be applied, simulating Workflow Templates
PROMPT = MESSAGE 

#### (3) Configure the Model request, simulating Workflow Orchestration
# Documentation: https://github.com/ollama/ollama/blob/main/docs/api.md
payload = create_payload(target="open-webui",
                         model="phi4:latest", 
                         prompt=PROMPT, 
                         temperature=0.5, 
                         num_ctx=2048, 
                         num_predict=1200) #Initially 300, changed it to 900. Then to 2000 and next to 1200

### YOU DON’T NEED TO CONFIGURE ANYTHING ELSE FROM THIS POINT
# Send out to the model
response_time, response = model_req(payload=payload)
print(response)
if response_time: print(f"Time taken: {response_time}s")
# Out:
# {'model': 'phi4:latest', 'messages': [{'role': 'user', 'content': 'Before performing the requirement analysis, first generate foundational knowledge on how AI-powered educational chatbots improve student learning, focusing on:\n- Cognitive and pedagogical principles behind effective tutoring.\n- How simplifying complex topics using toy examples improves retention.\n- The role of personalization in adaptive learning systems.\n- How AI models can be optimized to improve explanation clarity and engagement.\n- Key challenges in AI-driven education and how to address them.\n\nAfter generating this knowledge, proceed with the requirement analysis to enhance an existing Discord chatbot built using the Owlmind framework into an educational chatbot. The chatbot should simplify advanced topics for students using toy examples. Focus on educational improvements and provide:\n1. Additional educational features required, informed by the generated knowledge.\n2. Learning methodologies the chatbot should adopt based on effective AI tutoring strategies.\n3. Ways to personalize learning for different student levels, leveraging AI-driven adaptability.\n4. AI model improvements to enhance explanations and engagement.\n5. Example interactions demonstrating improved learning experience.\n\nFirst, generate the relevant knowledge step-by-step, then use that knowledge to structure the final requirement analysis. Format the response with clear sections and bullet points for readability.'}]}
# ### Foundational Knowledge on AI-Powered Educational Chatbots
#
# #### Cognitive and Pedagogical Principles Behind Effective Tutoring
# - **Active Learning**: Encourages students to engage actively with material through problem-solving and self-explanation.
# - **Scaffolding**: Provides temporary support structures to help learners reach higher levels of understanding, gradually removing them as competence increases.
# - **Feedback Mechanisms**: Immediate, specific feedback helps students understand mistakes and correct them in real-time.
# - **Zone of Proximal Development (ZPD)**: Tailors the difficulty of tasks just beyond what a student can do independently but achievable with guidance.
#
# #### Simplifying Complex Topics Using Toy Examples
# - **Concrete Representation**: Breaking down abstract concepts into tangible, relatable examples helps students grasp foundational ideas before tackling complexities.
# - **Incremental Complexity**: Starts simple and gradually increases complexity as understanding improves, facilitating better retention through manageable learning steps.
# - **Analogies and Metaphors**: Use familiar contexts to explain new or complex topics, enhancing comprehension and memory retention.
#
# #### Role of Personalization in Adaptive Learning Systems
# - **Individualized Pacing**: Adjusts the speed at which content is delivered based on student proficiency and engagement levels.
# - **Tailored Content Recommendations**: Suggests resources and problems suited to a learner's current understanding and learning style.
# - **Dynamic Difficulty Adjustment**: Modifies challenge levels in real-time to maintain optimal difficulty, preventing frustration or boredom.
#
# #### AI Model Optimization for Clarity and Engagement
# - **Natural Language Processing (NLP) Enhancements**: Improves the chatbot’s ability to understand nuanced student queries and generate clear, concise responses.
# - **Interactive Dialogue Systems**: Engages students through conversational interfaces that mimic human tutoring interactions.
# - **Multimodal Explanations**: Incorporates text, visuals, and interactive elements for comprehensive understanding.
#
# #### Key Challenges in AI-Driven Education
# - **Bias and Fairness**: Ensuring AI models do not perpetuate biases present in training data; requires diverse datasets and ongoing evaluation.
# - **Student Engagement**: Keeping students motivated over time can be challenging without the human touch of empathy and encouragement.
# - **Data Privacy**: Safeguarding student data from misuse while providing personalized learning experiences.
#
# ### Requirement Analysis for Enhancing a Discord Chatbot with Owlmind Framework
#
# #### 1. Additional Educational Features
# - **Interactive Toy Examples Module**: Develop scenarios that break down complex topics into simple, relatable examples.
# - **Adaptive Quiz System**: Implement quizzes that adjust in real-time based on student responses to tailor learning experiences.
# - **Progress Tracking and Reporting**: Provide students with insights into their learning journey, highlighting strengths and areas for improvement.
#
# #### 2. Learning Methodologies
# - **Scaffolding Techniques**: Introduce problem-solving steps incrementally, supporting the learner until they achieve independent understanding.
# - **Immediate Feedback Mechanisms**: Use AI to provide real-time feedback on student responses and guide them towards correct solutions.
# - **Peer Interaction Simulation**: Facilitate discussions among students in a controlled environment to mimic group study benefits.
#
# #### 3. Personalization Strategies
# - **Adaptive Learning Paths**: Design content paths that adapt based on individual learning speed, style, and history.
# - **Content Recommendation Engine**: Utilize AI to suggest additional resources or topics aligned with the student’s current level of understanding.
# - **Level-Based Challenges**: Offer tasks tailored to different proficiency levels, encouraging progression through mastery.
#
# #### 4. AI Model Improvements
# - **Enhanced NLP Capabilities**: Upgrade language models to better understand diverse student inputs and provide clearer explanations.
# - **Conversational Engagement Strategies**: Implement techniques like dialogue branching to maintain interactive and engaging conversations.
# - **Multimodal Learning Support**: Integrate visual aids, diagrams, and simulations within chatbot responses for enriched learning.
#
# #### 5. Example Interactions Demonstrating Improved Learning Experience
#
# **Interaction Scenario: Understanding Linear Algebra**
#
# - **Student Query**: "What is a matrix?"
#
#   - **Chatbot Response**: "Think of a matrix as a grid or table filled with numbers. It’s like organizing your data into rows and columns for easier manipulation. Let's try an example. Imagine you have two shopping lists, each with three items: apples, bananas, and oranges. Representing the quantities as a matrix helps us compare them easily."
#
# - **Student Follow-Up**: "Can matrices solve real-world problems?"
#
#   - **Chatbot Response**: "Absolutely! Matrices are used in computer graphics for transformations, in economics to model markets, and even in social networks to analyze connections. Let’s explore how they help in image processing by transforming a picture's pixels!"
#
# - **Adaptive Adjustment**: Based on student engagement and responses, the chatbot offers more detailed examples or redirects to simpler explanations if necessary.
#
# By leveraging these educational principles and AI capabilities, an enhanced Discord chatbot can provide a dynamic, personalized learning experience that simplifies complex topics through interactive toy examples.
# Time taken: 21.7s

# %%
##
## GENERATE KNOWLEDGE PROMPTING FOR REQUIREMENT ANALYSIS
##

from _pipeline import create_payload, model_req

#### (1) Adjust the inbounding Prompt, simulating inbounding requests from users or other systems
MESSAGE = ("Before performing the requirement analysis, first generate foundational knowledge on how AI-powered "
    "educational chatbots improve student learning, focusing on:\n"
    "- Cognitive and pedagogical principles behind effective tutoring.\n"
    "- How simplifying complex topics using toy examples improves retention.\n"
    "- The role of personalization in adaptive learning systems.\n"
    "- How AI models can be optimized to improve explanation clarity and engagement.\n"
    "- Key challenges in AI-driven education and how to address them.\n\n"
    "After generating this knowledge, proceed with the requirement analysis to enhance an existing Discord chatbot "
    "built using the Owlmind framework into an educational chatbot. The chatbot should simplify advanced topics for "
    "students using toy examples. Focus on educational improvements and provide:\n"
    "1. Additional educational features required, informed by the generated knowledge.\n"
    "2. Learning methodologies the chatbot should adopt based on effective AI tutoring strategies.\n"
    "3. Ways to personalize learning for different student levels, leveraging AI-driven adaptability.\n"
    "4. AI model improvements to enhance explanations and engagement.\n"
    "5. Example interactions demonstrating improved learning experience.\n\n"
    "First, generate the relevant knowledge step-by-step, then use that knowledge to structure the final requirement analysis. "
    "Format the response with clear sections and bullet points for readability.")

#### (2) Adjust the Prompt Engineering Technique to be applied, simulating Workflow Templates
PROMPT = MESSAGE 

#### (3) Configure the Model request, simulating Workflow Orchestration
# Documentation: https://github.com/ollama/ollama/blob/main/docs/api.md
payload = create_payload(target="open-webui",
                         model="phi4:latest", 
                         prompt=PROMPT, 
                         temperature=1.4, 
                         num_ctx=2048, 
                         num_predict=1200) #Initially 300, changed it to 900. Then to 2000 and next to 1200

### YOU DON’T NEED TO CONFIGURE ANYTHING ELSE FROM THIS POINT
# Send out to the model
response_time, response = model_req(payload=payload)
print(response)
if response_time: print(f"Time taken: {response_time}s")
